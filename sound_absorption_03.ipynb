# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# %matplotlib widget

# %%
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)
warnings.filterwarnings("ignore", category=pd.errors.PerformanceWarning)

# %% [markdown]
# ### Reference: Influence of hole shape on sound absorption of underwater anechoic layers
# #### https://www.sciencedirect.com/science/article/abs/pii/S0022460X1830227X

# %% [markdown]
# ### Import pre-defined class and function

# %%
# %run -i hole_shape_sound_absorption.py

# %% [markdown]
# ### Define the determinant of the coefficient matrix of eq(14) in the paper

# %%
determinant, mat = determinant_from_matrix()
mat
# Out:
# Matrix([
# [                                                                                                              -sqrt(-kz**2 + omega**2/cl**2)*besselj(1, b*sqrt(-kz**2 + omega**2/cl**2)),                                                                                                               -sqrt(-kz**2 + omega**2/cl**2)*bessely(1, b*sqrt(-kz**2 + omega**2/cl**2)),                                                                                      -I*kz*sqrt(-kz**2 + omega**2/ct**2)*besselj(1, b*sqrt(-kz**2 + omega**2/ct**2)),                                                                                      -I*kz*sqrt(-kz**2 + omega**2/ct**2)*bessely(1, b*sqrt(-kz**2 + omega**2/ct**2))],
# [(-2*mu*(-kz**2 + omega**2/cl**2) - lambda*omega**2/cl**2)*besselj(0, a*sqrt(-kz**2 + omega**2/cl**2)) + 2*mu*sqrt(-kz**2 + omega**2/cl**2)*besselj(1, a*sqrt(-kz**2 + omega**2/cl**2))/a, (-2*mu*(-kz**2 + omega**2/cl**2) - lambda*omega**2/cl**2)*bessely(0, a*sqrt(-kz**2 + omega**2/cl**2)) + 2*mu*sqrt(-kz**2 + omega**2/cl**2)*bessely(1, a*sqrt(-kz**2 + omega**2/cl**2))/a, 2*I*kz*mu*sqrt(-kz**2 + omega**2/ct**2)*(-sqrt(-kz**2 + omega**2/ct**2)*besselj(0, a*sqrt(-kz**2 + omega**2/ct**2)) + besselj(1, a*sqrt(-kz**2 + omega**2/ct**2))/a), 2*I*kz*mu*sqrt(-kz**2 + omega**2/ct**2)*(-sqrt(-kz**2 + omega**2/ct**2)*bessely(0, a*sqrt(-kz**2 + omega**2/ct**2)) + bessely(1, a*sqrt(-kz**2 + omega**2/ct**2))/a)],
# [                                                                                                    -2*I*kz*mu*sqrt(-kz**2 + omega**2/cl**2)*besselj(1, a*sqrt(-kz**2 + omega**2/cl**2)),                                                                                                     -2*I*kz*mu*sqrt(-kz**2 + omega**2/cl**2)*bessely(1, a*sqrt(-kz**2 + omega**2/cl**2)),                                                              mu*sqrt(-kz**2 + omega**2/ct**2)*(2*kz**2 - omega**2/ct**2)*besselj(1, a*sqrt(-kz**2 + omega**2/ct**2)),                                                              mu*sqrt(-kz**2 + omega**2/ct**2)*(2*kz**2 - omega**2/ct**2)*bessely(1, a*sqrt(-kz**2 + omega**2/ct**2))],
# [                                                                                                    -2*I*kz*mu*sqrt(-kz**2 + omega**2/cl**2)*besselj(1, b*sqrt(-kz**2 + omega**2/cl**2)),                                                                                                     -2*I*kz*mu*sqrt(-kz**2 + omega**2/cl**2)*bessely(1, b*sqrt(-kz**2 + omega**2/cl**2)),                                                              mu*sqrt(-kz**2 + omega**2/ct**2)*(2*kz**2 - omega**2/ct**2)*besselj(1, b*sqrt(-kz**2 + omega**2/ct**2)),                                                              mu*sqrt(-kz**2 + omega**2/ct**2)*(2*kz**2 - omega**2/ct**2)*bessely(1, b*sqrt(-kz**2 + omega**2/ct**2))]])

# %%
determinant
# Out:
# <function _lambdifygenerated(kz, a, b, mu, Dummy_11310, omega, cl, ct)>

# %%
# matrix_accurate_solution

# %% [markdown]
# ## Define an object of sound_performance for calculating sound absorption
# ### The default values are listed as below (all in SI units)
#
# Material of anechoic layer: rubber
#
# Young's modulus of rubber (GPa): 0.14
#
# Loss factor of rubber 0.23
#
# Poisson ratio of rubber 0.49
#
# Density of rubber (kg/m3): 1100
#
# Density of air (kg/m3): 1.21
#
# Shape: cone
#
# p = 4 mm
#
# q = 8 mm
#
# lh = 40 mm
#
# cell_radius = 15 mm
#
# num_segments = 100
#
# Density of water (kg/m3): 998
#
# Sound speed of water (m/s): 1483
#
# #### https://en.wikipedia.org/wiki/Lam%C3%A9_parameters

# %% [markdown]
# ### Define the frequency array by np.arange

# %%
# f_step = 25; Seg = 50
# f_step = 25; Seg = 100
# f_step = 50; Seg = 50
# f_step = 50; Seg = 100
# f_step = 100; Seg = 50
# f_step = 100; Seg = 100

# %%
frequency_array = np.arange(5, 10055, 50)
# frequency_array = np.arange(20, 120, 50)
frequency_array.shape
# Out:
# (201,)

# %%
frequency_array[-1]
# Out:
# 10005

# %% [markdown]
# ### Demo: Define all parameters by anechoic_sound_absorption()

# %%
cone_4_0_lr_01 = anechoic_sound_absorption(determinant, frequency_array,
                              fp = '/Users/cheng-hunglin/Documents/python_temp/', 
                              fn = 'cone_4_0_20260305_01.xlsx', 
                              material='rubber', shape='cone', 
                              p=4.0e-3, q=0.0e-3, la=50e-3, lh=40e-3, cell_radius=15e-3, 
                              theta=0.5, phi=3e-3, length_unit='m',
                              num_segments=100, layer_density=1100, air_density=1.21, 
                              Young_modulus=0.14e9, Poisson_ratio=0.49, loss_factor=0.23, 
                              medium_density=998, sound_speed_medium=1483, 
                              use_volume=True, 
                              is_rubber_end=True, lr=2.5e-3, no_air=False)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Solving wavenumber in determinant for shape = cone, p = 0.004, q = 0.0, Young's = 140000000.0
# Solving for all frequencies:   0%|          | 0/201 [00:00<?, ?it/s]
#   ... working at frequency = 5.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 55.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 105.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 155.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 205.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 255.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 305.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 355.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 405.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 455.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 505.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 555.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 605.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 655.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 705.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 755.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 805.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 855.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 905.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 955.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1005.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1055.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1105.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1155.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1205.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1255.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1305.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1355.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1405.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1455.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1505.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1555.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1605.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1655.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1705.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1755.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1805.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1855.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1905.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1955.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2005.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2055.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2105.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2155.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2205.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2255.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2305.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2355.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2405.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2455.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2505.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2555.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2605.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2655.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2705.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2755.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2805.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2855.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2905.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2955.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3005.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3055.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3105.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3155.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3205.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3255.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3305.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3355.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3405.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3455.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3505.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3555.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3605.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3655.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3705.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3755.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3805.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3855.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3905.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3955.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4005.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4055.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4105.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4155.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4205.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4255.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4305.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4355.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4405.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4455.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4505.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4555.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4605.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4655.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4705.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4755.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4805.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4855.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4905.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4955.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5005.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5055.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5105.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5155.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5205.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5255.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5305.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5355.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5405.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5455.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5505.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5555.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5605.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5655.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5705.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5755.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5805.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5855.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5905.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5955.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6005.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6055.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6105.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6155.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6205.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6255.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6305.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6355.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6405.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6455.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6505.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6555.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6605.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6655.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6705.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6755.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6805.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6855.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6905.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6955.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7005.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7055.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7105.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7155.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7205.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7255.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7305.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7355.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7405.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7455.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7505.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7555.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7605.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7655.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7705.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7755.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7805.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7855.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7905.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7955.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8005.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8055.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8105.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8155.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8205.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8255.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8305.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8355.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8405.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8455.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8505.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8555.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8605.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8655.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8705.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8755.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8805.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8855.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8905.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8955.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9005.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9055.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9105.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9155.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9205.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9255.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9305.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9355.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9405.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9455.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9505.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9555.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9605.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9655.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9705.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9755.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9805.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9855.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9905.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9955.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 10005.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
# self.frequency_array.shape[0] = 201 is same as self.wavenumer_array.shape[0] = 201
# Save file to /Users/cheng-hunglin/Documents/python_temp/cone_4_0_20260305_01.xlsx

# %%
plt.figure()
plt.plot(frequency_array, cone_4_0_lr_01.absorption_frequency(), label='cone_4_0')
plt.legend()
plt.show()
# Out:
# self.frequency_array.shape[0] = 201 is same as self.wavenumer_array.shape[0] = 201
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Example 01: cone shape

# %%
cone_4_4_lr_01 = anechoic_sound_absorption(determinant, frequency_array,
                              fp = '/Users/cheng-hunglin/Documents/python_temp/', 
                              fn = 'cone_4_4_20260305_01.xlsx', 
                              material='rubber', shape='cone', 
                              p=4.0e-3, q=4.0e-3, la=50e-3, lh=40e-3, cell_radius=15e-3, 
                              theta=0.5, phi=3e-3, length_unit='m',
                              num_segments=100, layer_density=1100, air_density=1.21, 
                              Young_modulus=0.14e9, Poisson_ratio=0.49, loss_factor=0.23, 
                              medium_density=998, sound_speed_medium=1483, 
                              use_volume=True, 
                              is_rubber_end=True, lr=2.5e-3, no_air=False)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Solving wavenumber in determinant for shape = cone, p = 0.004, q = 0.004, Young's = 140000000.0
# Solving for all frequencies:   0%|          | 0/201 [00:00<?, ?it/s]
#   ... working at frequency = 5.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 55.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 105.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 155.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 205.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 255.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 305.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 355.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 405.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 455.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 505.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 555.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 605.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 655.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 705.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 755.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 805.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 855.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 905.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 955.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1005.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1055.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1105.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1155.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1205.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1255.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1305.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1355.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1405.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1455.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1505.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1555.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1605.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1655.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1705.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1755.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1805.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1855.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1905.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1955.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2005.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2055.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2105.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2155.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2205.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2255.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2305.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2355.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2405.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2455.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2505.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2555.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2605.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2655.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2705.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2755.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2805.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2855.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2905.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2955.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3005.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3055.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3105.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3155.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3205.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3255.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3305.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3355.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3405.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3455.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3505.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3555.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3605.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3655.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3705.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3755.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3805.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3855.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3905.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3955.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4005.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4055.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4105.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4155.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4205.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4255.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4305.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4355.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4405.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4455.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4505.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4555.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4605.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4655.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4705.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4755.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4805.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4855.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4905.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4955.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5005.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5055.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5105.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5155.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5205.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5255.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5305.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5355.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5405.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5455.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5505.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5555.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5605.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5655.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5705.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5755.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5805.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5855.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5905.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5955.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6005.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6055.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6105.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6155.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6205.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6255.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6305.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6355.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6405.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6455.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6505.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6555.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6605.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6655.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6705.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6755.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6805.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6855.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6905.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6955.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7005.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7055.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7105.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7155.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7205.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7255.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7305.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7355.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7405.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7455.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7505.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7555.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7605.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7655.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7705.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7755.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7805.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7855.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7905.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7955.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8005.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8055.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8105.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8155.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8205.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8255.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8305.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8355.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8405.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8455.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8505.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8555.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8605.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8655.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8705.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8755.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8805.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8855.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8905.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8955.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9005.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9055.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9105.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9155.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9205.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9255.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9305.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9355.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9405.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9455.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9505.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9555.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9605.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9655.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9705.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9755.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9805.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9855.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9905.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9955.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 10005.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
# self.frequency_array.shape[0] = 201 is same as self.wavenumer_array.shape[0] = 201
# Save file to /Users/cheng-hunglin/Documents/python_temp/cone_4_4_20260305_01.xlsx

# %%
cone_4_8_lr_01 = anechoic_sound_absorption(determinant, frequency_array,
                              fp = '/Users/cheng-hunglin/Documents/python_temp/', 
                              fn = 'cone_4_8_20260305_01.xlsx', 
                              material='rubber', shape='cone', 
                              p=4.0e-3, q=8.0e-3, la=50e-3, lh=40e-3, cell_radius=15e-3, 
                              theta=0.5, phi=3e-3, length_unit='m',
                              num_segments=100, layer_density=1100, air_density=1.21, 
                              Young_modulus=0.14e9, Poisson_ratio=0.49, loss_factor=0.23, 
                              medium_density=998, sound_speed_medium=1483, 
                              use_volume=True, 
                              is_rubber_end=True, lr=2.5e-3, no_air=False)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Solving wavenumber in determinant for shape = cone, p = 0.004, q = 0.008, Young's = 140000000.0
# Solving for all frequencies:   0%|          | 0/201 [00:00<?, ?it/s]
#   ... working at frequency = 5.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 55.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 105.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 155.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 205.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 255.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 305.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 355.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 405.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 455.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 505.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 555.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 605.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 655.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 705.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 755.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 805.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 855.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 905.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 955.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1005.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1055.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1105.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1155.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1205.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1255.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1305.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1355.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1405.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1455.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1505.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1555.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1605.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1655.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1705.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1755.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1805.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1855.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1905.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 1955.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2005.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2055.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2105.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2155.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2205.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2255.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2305.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2355.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2405.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2455.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2505.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2555.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2605.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2655.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2705.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2755.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2805.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2855.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2905.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 2955.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3005.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3055.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3105.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3155.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3205.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3255.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3305.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3355.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3405.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3455.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3505.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3555.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3605.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3655.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3705.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3755.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3805.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3855.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3905.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 3955.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4005.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4055.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4105.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4155.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4205.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4255.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4305.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4355.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4405.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4455.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4505.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4555.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4605.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4655.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4705.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4755.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4805.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4855.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4905.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 4955.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5005.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5055.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5105.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5155.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5205.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5255.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5305.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5355.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5405.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5455.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5505.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5555.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5605.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5655.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5705.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5755.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5805.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5855.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5905.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 5955.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6005.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6055.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6105.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6155.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6205.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6255.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6305.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6355.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6405.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6455.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6505.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6555.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6605.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6655.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6705.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6755.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6805.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6855.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6905.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 6955.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7005.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7055.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7105.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7155.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7205.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7255.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7305.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7355.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7405.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7455.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7505.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7555.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7605.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7655.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7705.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7755.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7805.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7855.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7905.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 7955.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8005.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8055.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8105.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8155.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8205.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8255.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8305.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8355.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8405.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8455.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8505.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8555.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8605.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8655.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8705.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8755.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8805.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8855.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8905.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 8955.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9005.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9055.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9105.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9155.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9205.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9255.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9305.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9355.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9405.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9455.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9505.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9555.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9605.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9655.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9705.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9755.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9805.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9855.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9905.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 9955.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
#   ... working at frequency = 10005.0 Hz:   0%|          | 0/106 [00:00<?, ?it/s]
# self.frequency_array.shape[0] = 201 is same as self.wavenumer_array.shape[0] = 201
# Save file to /Users/cheng-hunglin/Documents/python_temp/cone_4_8_20260305_01.xlsx

# %%
plt.figure()
plt.plot(frequency_array, cone_4_0_lr_01.absorption_frequency(), label='cone_4_0')
plt.plot(frequency_array, cone_4_4_lr_01.absorption_frequency(), label='cone_4_4')
plt.plot(frequency_array, cone_4_8_lr_01.absorption_frequency(), label='cone_4_8')
plt.legend()
plt.show()
# Out:
# self.frequency_array.shape[0] = 201 is same as self.wavenumer_array.shape[0] = 201
# self.frequency_array.shape[0] = 201 is same as self.wavenumer_array.shape[0] = 201
# self.frequency_array.shape[0] = 201 is same as self.wavenumer_array.shape[0] = 201
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Example 02: calculate absorption of all rubber layer

# %%
cone_4_0_noair_01 = anechoic_sound_absorption(determinant, frequency_array,
                              fp = '/Users/cheng-hunglin/Documents/python_temp/', 
                              fn = 'cone_4_0_20260305_noair_01.xlsx', 
                              material='rubber', shape='cone', 
                              p=4.0e-3, q=0.0e-3, la=50e-3, lh=40e-3, cell_radius=15e-3, 
                              theta=0.5, phi=3e-3, length_unit='m',
                              num_segments=100, layer_density=1100, air_density=1.21, 
                              Young_modulus=0.14e9, Poisson_ratio=0.49, loss_factor=0.23, 
                              medium_density=998, sound_speed_medium=1483, 
                              use_volume=True, 
                              is_rubber_end=True, lr=2.5e-3, no_air=True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# self.frequency_array.shape = (201,) is same as self.wavenumer_array.shape = (201,)
# Save file to /Users/cheng-hunglin/Documents/python_temp/cone_4_0_20260305_noair_01.xlsx

# %%
cone_4_4_noair_01 = anechoic_sound_absorption(determinant, frequency_array,
                              fp = '/Users/cheng-hunglin/Documents/python_temp/', 
                              fn = 'cone_4_4_20260305_noair_01.xlsx', 
                              material='rubber', shape='cone', 
                              p=4.0e-3, q=4.0e-3, la=50e-3, lh=40e-3, cell_radius=15e-3, 
                              theta=0.5, phi=3e-3, length_unit='m',
                              num_segments=100, layer_density=1100, air_density=1.21, 
                              Young_modulus=0.14e9, Poisson_ratio=0.49, loss_factor=0.23, 
                              medium_density=998, sound_speed_medium=1483, 
                              use_volume=True, 
                              is_rubber_end=True, lr=2.5e-3, no_air=True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# self.frequency_array.shape = (201,) is same as self.wavenumer_array.shape = (201,)
# Save file to /Users/cheng-hunglin/Documents/python_temp/cone_4_4_20260305_noair_01.xlsx

# %%
cone_4_8_noair_01 = anechoic_sound_absorption(determinant, frequency_array,
                              fp = '/Users/cheng-hunglin/Documents/python_temp/', 
                              fn = 'cone_4_8_20260305_noair_01.xlsx', 
                              material='rubber', shape='cone', 
                              p=4.0e-3, q=8.0e-3, la=50e-3, lh=40e-3, cell_radius=15e-3, 
                              theta=0.5, phi=3e-3, length_unit='m',
                              num_segments=100, layer_density=1100, air_density=1.21, 
                              Young_modulus=0.14e9, Poisson_ratio=0.49, loss_factor=0.23, 
                              medium_density=998, sound_speed_medium=1483, 
                              use_volume=True, 
                              is_rubber_end=True, lr=2.5e-3, no_air=True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# self.frequency_array.shape = (201,) is same as self.wavenumer_array.shape = (201,)
# Save file to /Users/cheng-hunglin/Documents/python_temp/cone_4_8_20260305_noair_01.xlsx

# %%
plt.figure()
plt.plot(frequency_array, cone_4_0_noair_01.absorption_frequency(), label='cone_4_0 no air')
plt.plot(frequency_array, cone_4_4_noair_01.absorption_frequency(), label='cone_4_4 no air')
plt.plot(frequency_array, cone_4_8_noair_01.absorption_frequency(), label='cone_4_8 no air')
plt.legend()
plt.show()
# Out:
# self.frequency_array.shape = (201,) is same as self.wavenumer_array.shape = (201,)
# self.frequency_array.shape = (201,) is same as self.wavenumer_array.shape = (201,)
# self.frequency_array.shape = (201,) is same as self.wavenumer_array.shape = (201,)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
cone_4_8_noair_01.loss_factor
# Out:
# -0.23

# %% [markdown]
# ### Example 03: various thicknesses (la) of all rubber layer

# %%
la_10_noair_01 = anechoic_sound_absorption(determinant, frequency_array,
                              fp = '/Users/cheng-hunglin/Documents/python_temp/', 
                              fn = 'la_10_20260305_noair_01.xlsx', 
                              material='rubber', shape='cone', 
                              p=0.0e-3, q=0.0e-3, la=10e-3, lh=5e-3, cell_radius=15e-3, 
                              theta=0.5, phi=3e-3, length_unit='m',
                              num_segments=100, layer_density=1100, air_density=1.21, 
                              Young_modulus=0.14e9, Poisson_ratio=0.49, loss_factor=0.23, 
                              medium_density=998, sound_speed_medium=1483, 
                              use_volume=True, 
                              is_rubber_end=True, lr=2.5e-3, no_air=True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# self.frequency_array.shape = (201,) is same as self.wavenumer_array.shape = (201,)
# Save file to /Users/cheng-hunglin/Documents/python_temp/la_10_20260305_noair_01.xlsx

# %%
la_30_noair_01 = anechoic_sound_absorption(determinant, frequency_array,
                              fp = '/Users/cheng-hunglin/Documents/python_temp/', 
                              fn = 'la_30_20260305_noair_01.xlsx', 
                              material='rubber', shape='cone', 
                              p=0.0e-3, q=0.0e-3, la=30e-3, lh=5e-3, cell_radius=15e-3, 
                              theta=0.5, phi=3e-3, length_unit='m',
                              num_segments=100, layer_density=1100, air_density=1.21, 
                              Young_modulus=0.14e9, Poisson_ratio=0.49, loss_factor=0.23, 
                              medium_density=998, sound_speed_medium=1483, 
                              use_volume=True, 
                              is_rubber_end=True, lr=2.5e-3, no_air=True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# self.frequency_array.shape = (201,) is same as self.wavenumer_array.shape = (201,)
# Save file to /Users/cheng-hunglin/Documents/python_temp/la_30_20260305_noair_01.xlsx

# %%
la_50_noair_01 = anechoic_sound_absorption(determinant, frequency_array,
                              fp = '/Users/cheng-hunglin/Documents/python_temp/', 
                              fn = 'la_50_20260305_noair_01.xlsx', 
                              material='rubber', shape='cone', 
                              p=0.0e-3, q=0.0e-3, la=50e-3, lh=5e-3, cell_radius=15e-3, 
                              theta=0.5, phi=3e-3, length_unit='m',
                              num_segments=100, layer_density=1100, air_density=1.21, 
                              Young_modulus=0.14e9, Poisson_ratio=0.49, loss_factor=0.23, 
                              medium_density=998, sound_speed_medium=1483, 
                              use_volume=True, 
                              is_rubber_end=True, lr=2.5e-3, no_air=True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# self.frequency_array.shape = (201,) is same as self.wavenumer_array.shape = (201,)
# Save file to /Users/cheng-hunglin/Documents/python_temp/la_50_20260305_noair_01.xlsx

# %%
la_70_noair_01 = anechoic_sound_absorption(determinant, frequency_array,
                              fp = '/Users/cheng-hunglin/Documents/python_temp/', 
                              fn = 'la_70_20260305_noair_01.xlsx', 
                              material='rubber', shape='cone', 
                              p=0.0e-3, q=0.0e-3, la=70e-3, lh=5e-3, cell_radius=15e-3, 
                              theta=0.5, phi=3e-3, length_unit='m',
                              num_segments=100, layer_density=1100, air_density=1.21, 
                              Young_modulus=0.14e9, Poisson_ratio=0.49, loss_factor=0.23, 
                              medium_density=998, sound_speed_medium=1483, 
                              use_volume=True, 
                              is_rubber_end=True, lr=2.5e-3, no_air=True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# self.frequency_array.shape = (201,) is same as self.wavenumer_array.shape = (201,)
# Save file to /Users/cheng-hunglin/Documents/python_temp/la_70_20260305_noair_01.xlsx

# %%
la_90_noair_01 = anechoic_sound_absorption(determinant, frequency_array,
                              fp = '/Users/cheng-hunglin/Documents/python_temp/', 
                              fn = 'la_90_20260305_noair_01.xlsx', 
                              material='rubber', shape='cone', 
                              p=0.0e-3, q=0.0e-3, la=90e-3, lh=5e-3, cell_radius=15e-3, 
                              theta=0.5, phi=3e-3, length_unit='m',
                              num_segments=100, layer_density=1100, air_density=1.21, 
                              Young_modulus=0.14e9, Poisson_ratio=0.49, loss_factor=0.23, 
                              medium_density=998, sound_speed_medium=1483, 
                              use_volume=True, 
                              is_rubber_end=True, lr=2.5e-3, no_air=True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# self.frequency_array.shape = (201,) is same as self.wavenumer_array.shape = (201,)
# Save file to /Users/cheng-hunglin/Documents/python_temp/la_90_20260305_noair_01.xlsx

# %%
la_110_noair_01 = anechoic_sound_absorption(determinant, frequency_array,
                              fp = '/Users/cheng-hunglin/Documents/python_temp/', 
                              fn = 'la_110_20260305_noair_01.xlsx', 
                              material='rubber', shape='cone', 
                              p=0.0e-3, q=0.0e-3, la=110e-3, lh=5e-3, cell_radius=15e-3, 
                              theta=0.5, phi=3e-3, length_unit='m',
                              num_segments=100, layer_density=1100, air_density=1.21, 
                              Young_modulus=0.14e9, Poisson_ratio=0.49, loss_factor=0.23, 
                              medium_density=998, sound_speed_medium=1483, 
                              use_volume=True, 
                              is_rubber_end=True, lr=2.5e-3, no_air=True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# self.frequency_array.shape = (201,) is same as self.wavenumer_array.shape = (201,)
# Save file to /Users/cheng-hunglin/Documents/python_temp/la_110_20260305_noair_01.xlsx

# %%
plt.figure()
plt.plot(frequency_array, la_10_noair_01.absorption_frequency(), label='la_10_noair')
plt.plot(frequency_array, la_30_noair_01.absorption_frequency(), label='la_30_noair')
plt.plot(frequency_array, la_50_noair_01.absorption_frequency(), label='la_50_noair')
plt.plot(frequency_array, la_70_noair_01.absorption_frequency(), label='la_70_noair')
plt.plot(frequency_array, la_90_noair_01.absorption_frequency(), label='la_90_noair')
plt.plot(frequency_array, la_110_noair_01.absorption_frequency(), label='la_110_noair')
plt.legend()
plt.show()
# Out:
# self.frequency_array.shape = (201,) is same as self.wavenumer_array.shape = (201,)
# self.frequency_array.shape = (201,) is same as self.wavenumer_array.shape = (201,)
# self.frequency_array.shape = (201,) is same as self.wavenumer_array.shape = (201,)
# self.frequency_array.shape = (201,) is same as self.wavenumer_array.shape = (201,)
# self.frequency_array.shape = (201,) is same as self.wavenumer_array.shape = (201,)
# self.frequency_array.shape = (201,) is same as self.wavenumer_array.shape = (201,)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
