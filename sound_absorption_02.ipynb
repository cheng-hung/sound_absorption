# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# %matplotlib widget

# %%
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)
warnings.filterwarnings("ignore", category=pd.errors.PerformanceWarning)

# %% [markdown]
# ### Reference: Influence of hole shape on sound absorption of underwater anechoic layers
# #### https://www.sciencedirect.com/science/article/abs/pii/S0022460X1830227X

# %% [markdown]
# ### Import pre-defined class and function

# %%
# %run -i hole_shape_sound_absorption.py

# %% [markdown]
# ### Define the determinant of the coefficient matrix of eq(14) in the paper

# %%
determinant, mat = determinant_from_matrix()
mat
# Out:
# Matrix([
# [                                                                                                              -sqrt(-kz**2 + omega**2/cl**2)*besselj(1, b*sqrt(-kz**2 + omega**2/cl**2)),                                                                                                               -sqrt(-kz**2 + omega**2/cl**2)*bessely(1, b*sqrt(-kz**2 + omega**2/cl**2)),                                                                                      -I*kz*sqrt(-kz**2 + omega**2/ct**2)*besselj(1, b*sqrt(-kz**2 + omega**2/ct**2)),                                                                                      -I*kz*sqrt(-kz**2 + omega**2/ct**2)*bessely(1, b*sqrt(-kz**2 + omega**2/ct**2))],
# [(-2*mu*(-kz**2 + omega**2/cl**2) - lambda*omega**2/cl**2)*besselj(0, a*sqrt(-kz**2 + omega**2/cl**2)) + 2*mu*sqrt(-kz**2 + omega**2/cl**2)*besselj(1, a*sqrt(-kz**2 + omega**2/cl**2))/a, (-2*mu*(-kz**2 + omega**2/cl**2) - lambda*omega**2/cl**2)*bessely(0, a*sqrt(-kz**2 + omega**2/cl**2)) + 2*mu*sqrt(-kz**2 + omega**2/cl**2)*bessely(1, a*sqrt(-kz**2 + omega**2/cl**2))/a, 2*I*kz*mu*sqrt(-kz**2 + omega**2/ct**2)*(-sqrt(-kz**2 + omega**2/ct**2)*besselj(0, a*sqrt(-kz**2 + omega**2/ct**2)) + besselj(1, a*sqrt(-kz**2 + omega**2/ct**2))/a), 2*I*kz*mu*sqrt(-kz**2 + omega**2/ct**2)*(-sqrt(-kz**2 + omega**2/ct**2)*bessely(0, a*sqrt(-kz**2 + omega**2/ct**2)) + bessely(1, a*sqrt(-kz**2 + omega**2/ct**2))/a)],
# [                                                                                                    -2*I*kz*mu*sqrt(-kz**2 + omega**2/cl**2)*besselj(1, a*sqrt(-kz**2 + omega**2/cl**2)),                                                                                                     -2*I*kz*mu*sqrt(-kz**2 + omega**2/cl**2)*bessely(1, a*sqrt(-kz**2 + omega**2/cl**2)),                                                              mu*sqrt(-kz**2 + omega**2/ct**2)*(2*kz**2 - omega**2/ct**2)*besselj(1, a*sqrt(-kz**2 + omega**2/ct**2)),                                                              mu*sqrt(-kz**2 + omega**2/ct**2)*(2*kz**2 - omega**2/ct**2)*bessely(1, a*sqrt(-kz**2 + omega**2/ct**2))],
# [                                                                                                    -2*I*kz*mu*sqrt(-kz**2 + omega**2/cl**2)*besselj(1, b*sqrt(-kz**2 + omega**2/cl**2)),                                                                                                     -2*I*kz*mu*sqrt(-kz**2 + omega**2/cl**2)*bessely(1, b*sqrt(-kz**2 + omega**2/cl**2)),                                                              mu*sqrt(-kz**2 + omega**2/ct**2)*(2*kz**2 - omega**2/ct**2)*besselj(1, b*sqrt(-kz**2 + omega**2/ct**2)),                                                              mu*sqrt(-kz**2 + omega**2/ct**2)*(2*kz**2 - omega**2/ct**2)*bessely(1, b*sqrt(-kz**2 + omega**2/ct**2))]])

# %%
determinant
# Out:
# <function _lambdifygenerated(kz, a, b, mu, Dummy_11310, omega, cl, ct)>

# %%
# matrix_accurate_solution

# %% [markdown]
# ## Define an object of sound_performance for calculating sound absorption
# ### The default values are listed as below (all in SI units)
#
# Material of anechoic layer: rubber
#
# Young's modulus of rubber (GPa): 0.14
#
# Loss factor of rubber 0.23
#
# Poisson ratio of rubber 0.49
#
# Density of rubber (kg/m3): 1100
#
# Density of air (kg/m3): 1.21
#
# Shape: cone
#
# p = 4 mm
#
# q = 8 mm
#
# lh = 40 mm
#
# cell_radius = 15 mm
#
# num_segments = 100
#
# Density of water (kg/m3): 998
#
# Sound speed of water (m/s): 1483
#
# #### https://en.wikipedia.org/wiki/Lam%C3%A9_parameters

# %% [markdown]
# ### Define the frequency array by np.arange

# %%
# f_step = 25; Seg = 50
# f_step = 25; Seg = 100
# f_step = 50; Seg = 50
# f_step = 50; Seg = 100
# f_step = 100; Seg = 50
# f_step = 100; Seg = 100

# %%
# frequency_array = np.arange(10, 305, 50)
frequency_array = np.arange(20, 10020, 50)
frequency_array.shape
# Out:
# (200,)

# %%
# np.round(np.arange(5188, 5190, .2), decimals=2).tolist()

# %%
# frequency_array = list(range(10, 5103, 50)) + list(range(5103, 5203, 1)) + list(range(5212, 10022, 50))
# frequency_array = list(range(10, 5103, 50)) + list(range(5061, 5213, 1))
# frequency_array = list(range(10, 3909, 50))  + np.round(np.arange(3861, 5240, 20), decimals=3).tolist() + list(range(5240, 10052, 50))

# %%
# list(range(10, 3909, 50))[-1]
# np.round(np.arange(3861, 5240, 0.01), decimals=3)[-1]
# list(range(5240, 10052, 50))[-1]

# %%
# frequency_array.reverse()

# %%
# frequency_array = np.asarray(frequency_array)

# %%
# frequency_array.shape

# %% [markdown]
# ### Example 01: define all parameters by anechoic_sound_absorption()

# %%
cone_3_3_lr_01 = anechoic_sound_absorption(determinant, frequency_array,
                              fp = '/Users/cheng-hunglin/Documents/python_temp/', 
                              fn = 'test_20251229_01.xlsx', 
                              material='rubber', shape='cone', 
                              p=3.0e-3, q=3.0e-3, la=25e-3, lh=20e-3, cell_radius=7.5e-3, 
                              theta=0.5, phi=3e-3, length_unit='m',
                              num_segments=100, layer_density=1100, air_density=1.21, 
                              Young_modulus=0.14e9, Poisson_ratio=0.49, loss_factor=0.23, 
                              medium_density=998, sound_speed_medium=1483, 
                              use_volume=True, 
                              is_rubber_end=True, lr=2.5e-3)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Solving wavenumber in determinant for shape = cone, p = 0.003, q = 0.003, Young's = 140000000.0
# Solving for all frequencies:   0%|          | 0/200 [00:00<?, ?it/s]
#   ... working at frequency = 20.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 70.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 120.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 170.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 220.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 270.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 320.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 370.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 420.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 470.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 520.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 570.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 620.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 670.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 720.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 770.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 820.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 870.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 920.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 970.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 1020.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 1070.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 1120.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 1170.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 1220.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 1270.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 1320.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 1370.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 1420.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 1470.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 1520.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 1570.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 1620.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 1670.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 1720.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 1770.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 1820.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 1870.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 1920.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 1970.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 2020.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 2070.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 2120.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 2170.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 2220.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 2270.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 2320.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 2370.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 2420.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 2470.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 2520.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 2570.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 2620.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 2670.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 2720.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 2770.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 2820.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 2870.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 2920.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 2970.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 3020.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 3070.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 3120.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 3170.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 3220.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 3270.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 3320.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 3370.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 3420.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 3470.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 3520.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 3570.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 3620.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 3670.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 3720.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 3770.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 3820.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 3870.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 3920.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 3970.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 4020.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 4070.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 4120.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 4170.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 4220.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 4270.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 4320.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 4370.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 4420.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 4470.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 4520.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 4570.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 4620.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 4670.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 4720.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 4770.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 4820.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 4870.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 4920.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 4970.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 5020.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 5070.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 5120.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 5170.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 5220.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 5270.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 5320.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 5370.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 5420.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 5470.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 5520.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 5570.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 5620.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 5670.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 5720.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 5770.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 5820.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 5870.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 5920.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 5970.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 6020.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 6070.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 6120.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 6170.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 6220.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 6270.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 6320.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 6370.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 6420.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 6470.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 6520.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 6570.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 6620.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 6670.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 6720.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 6770.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 6820.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 6870.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 6920.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 6970.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 7020.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 7070.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 7120.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 7170.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 7220.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 7270.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 7320.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 7370.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 7420.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 7470.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 7520.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 7570.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 7620.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 7670.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 7720.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 7770.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 7820.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 7870.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 7920.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 7970.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 8020.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 8070.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 8120.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 8170.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 8220.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 8270.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 8320.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 8370.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 8420.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 8470.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 8520.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 8570.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 8620.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 8670.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 8720.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 8770.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 8820.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 8870.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 8920.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 8970.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 9020.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 9070.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 9120.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 9170.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 9220.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 9270.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 9320.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 9370.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 9420.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 9470.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 9520.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 9570.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 9620.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 9670.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 9720.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 9770.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 9820.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 9870.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 9920.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
#   ... working at frequency = 9970.0 Hz:   0%|          | 0/112 [00:00<?, ?it/s]
# self.frequency_array.shape[0] = 200 is same as self.wavenumer_array.shape[0] = 200
# Save file to /Users/cheng-hunglin/Documents/python_temp/test_20251229_01.xlsx

# %%
plt.figure()
plt.plot(frequency_array, cone_3_3_lr_01.absorption_frequency())
plt.show()
# Out:
# self.frequency_array.shape[0] = 200 is same as self.wavenumer_array.shape[0] = 200
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
cone_3_3_lr_00 = anechoic_sound_absorption(determinant, frequency_array,
                              fp = '/Users/cheng-hunglin/Documents/python_temp/', 
                              fn = '20251229_cone_3_3_lr_00.xlsx', 
                              material='rubber', shape='cone', 
                              p=3.0e-3, q=3.0e-3, la=25e-3, lh=20e-3, cell_radius=7.5e-3, 
                              theta=0.5, phi=3e-3, length_unit='m',
                              num_segments=100, layer_density=1100, air_density=1.21, 
                              Young_modulus=0.14e9, Poisson_ratio=0.49, loss_factor=0.23, 
                              medium_density=998, sound_speed_medium=1483, 
                              use_volume=True, 
                              is_rubber_end=False, lr=2.5e-3)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Solving wavenumber in determinant for shape = cone, p = 0.003, q = 0.003, Young's = 140000000.0
# Solving for all frequencies:   0%|          | 0/200 [00:00<?, ?it/s]
#   ... working at frequency = 20.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 70.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 120.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 170.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 220.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 270.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 320.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 370.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 420.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 470.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 520.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 570.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 620.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 670.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 720.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 770.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 820.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 870.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 920.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 970.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 1020.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 1070.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 1120.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 1170.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 1220.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 1270.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 1320.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 1370.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 1420.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 1470.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 1520.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 1570.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 1620.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 1670.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 1720.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 1770.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 1820.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 1870.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 1920.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 1970.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 2020.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 2070.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 2120.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 2170.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 2220.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 2270.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 2320.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 2370.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 2420.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 2470.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 2520.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 2570.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 2620.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 2670.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 2720.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 2770.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 2820.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 2870.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 2920.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 2970.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 3020.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 3070.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 3120.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 3170.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 3220.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 3270.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 3320.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 3370.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 3420.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 3470.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 3520.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 3570.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 3620.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 3670.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 3720.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 3770.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 3820.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 3870.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 3920.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 3970.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 4020.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 4070.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 4120.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 4170.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 4220.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 4270.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 4320.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 4370.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 4420.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 4470.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 4520.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 4570.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 4620.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 4670.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 4720.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 4770.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 4820.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 4870.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 4920.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 4970.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 5020.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 5070.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 5120.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 5170.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 5220.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 5270.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 5320.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 5370.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 5420.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 5470.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 5520.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 5570.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 5620.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 5670.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 5720.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 5770.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 5820.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 5870.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 5920.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 5970.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 6020.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 6070.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 6120.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 6170.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 6220.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 6270.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 6320.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 6370.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 6420.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 6470.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 6520.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 6570.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 6620.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 6670.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 6720.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 6770.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 6820.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 6870.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 6920.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 6970.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 7020.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 7070.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 7120.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 7170.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 7220.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 7270.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 7320.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 7370.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 7420.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 7470.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 7520.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 7570.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 7620.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 7670.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 7720.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 7770.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 7820.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 7870.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 7920.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 7970.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 8020.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 8070.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 8120.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 8170.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 8220.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 8270.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 8320.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 8370.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 8420.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 8470.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 8520.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 8570.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 8620.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 8670.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 8720.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 8770.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 8820.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 8870.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 8920.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 8970.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 9020.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 9070.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 9120.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 9170.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 9220.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 9270.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 9320.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 9370.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 9420.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 9470.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 9520.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 9570.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 9620.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 9670.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 9720.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 9770.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 9820.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 9870.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 9920.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
#   ... working at frequency = 9970.0 Hz:   0%|          | 0/100 [00:00<?, ?it/s]
# self.frequency_array.shape[0] = 200 is same as self.wavenumer_array.shape[0] = 200
# Save file to /Users/cheng-hunglin/Documents/python_temp/20251229_cone_3_3_lr_00.xlsx

# %%
plt.figure()
plt.plot(frequency_array, cone_3_3_lr_01.absorption_frequency(), label='steel_end')
plt.plot(frequency_array, cone_3_3_lr_00.absorption_frequency(), label='rubber_end')
plt.legend()
plt.show()
# Out:
# self.frequency_array.shape[0] = 200 is same as self.wavenumer_array.shape[0] = 200
# self.frequency_array.shape[0] = 200 is same as self.wavenumer_array.shape[0] = 200
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# frequency_array = np.arange(10, 10052, 25)
# sin_3_4_05_vol_v1_02 = anechoic_sound_absorption(determinant, frequency_array,
#                               fp = '/Users/chenghunglin/Documents/sound_absorption_test/', 
#                               fn = 'sin_3_4_05_vol_v1_02.xlsx', 
#                               material='rubber', shape='sin', 
#                               p=3e-3, q=4e-3, lh=40e-3, cell_radius=15e-3, 
#                               theta=0.5, phi=3e-3, length_unit='m',
#                               num_segments=100, layer_density=1100, air_density=1.21, 
#                               Young_modulus=0.14e9, Poisson_ratio=0.49, loss_factor=0.23, 
#                               medium_density=998, sound_speed_medium=1483, 
#                               use_volume=True)
